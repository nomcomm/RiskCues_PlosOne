# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.getcwd()
# Out:
# '/Users/Ralf/My_Cloud/RalfsFunctions/GITHUB/nomcomm/riskcues/scripts'

# %%
data_set = "/Users/Ralf/My_Cloud/RalfsFunctions/GITHUB/nomcomm/riskcues/data/setA_001-120.txt"
df = pd.read_csv(data_set, sep ='\t')
df.head()
# Out:
#    No  Sex  BildNr   Risk  Trust  Health  Attractiveness  \
# 0   1    0       1  3.550  4.150   4.200           2.775
# 1   2    0       2  3.500  4.125   4.775           4.525
# 2   3    0       3  4.775  3.725   3.775           4.275
# 3   4    0       4  4.475  3.300   3.800           4.225
# 4   5    0       5  4.725  3.825   3.725           4.175
#
#     CUE1_Appearance1_Ungroomed (vs. groomed) appearance_Abstract_2  \
# 0                                              4.500
# 1                                              2.750
# 2                                              4.625
# 3                                              3.625
# 4                                              2.375
#
#     CUE2_Appearance2_Lot of (vs. no) body adornment_Abstract_0  \
# 0                                              4.125
# 1                                              2.125
# 2                                              4.625
# 3                                              5.125
# 4                                              3.250
#
#     CUE3_Appearance3_Unshaved (vs. shaved)_Abstract_0  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                         ...                        \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
#
#     CUE64_Skin1_Unhealthy (vs. healthy) skin_Abstract_1  \
# 0                                              4.375
# 1                                              2.750
# 2                                              3.000
# 3                                              3.500
# 4                                              2.375
#
#     CUE65_Skin2_Pale (vs. tanned) skin_Abstract_0  \
# 0                                           3.250
# 1                                           3.250
# 2                                           6.000
# 3                                           4.875
# 4                                           4.750
#
#     CUE66_Skin3_Pimply (vs. pimple-free) skin_Abstract_0  \
# 0                                              3.750
# 1                                              3.125
# 2                                              2.375
# 3                                              3.375
# 4                                              2.250
#
#     CUE67_Skin4_Many (vs. few) skin folds_Abstract_0  \
# 0                                              2.500
# 1                                              1.500
# 2                                              1.625
# 3                                              1.250
# 4                                              2.000
#
#     CUE68_Skin5_Spotty (vs. spot-free) skin_Abstract_0  \
# 0                                              2.875
# 1                                              1.750
# 2                                              1.500
# 3                                              2.250
# 4                                              2.625
#
#     CUE69_Skin6_Greasy (vs. dry) skin_Abstract_0  \
# 0                                          5.625
# 1                                          4.000
# 2                                          3.250
# 3                                          5.000
# 4                                          4.250
#
#     CUE70_Skin7_Lots of (vs. no) skin visible_Abstract_0  \
# 0                                              6.125
# 1                                              5.250
# 2                                              6.625
# 3                                              5.000
# 4                                              3.125
#
#     CUE71_View1_Coquettish (vs. no coquettish) gaze_Abstract_1  \
# 0                                             2.0000
# 1                                             5.1250
# 2                                             2.5000
# 3                                             4.5000
# 4                                             4.5714
#
#     CUE72_View2_Averted (vs. front-facing) gaze_Abstract_0  \
# 0                                              1.000
# 1                                              1.250
# 2                                              1.625
# 3                                              1.750
# 4                                              1.625
#
#     CUE73_View3_Tired (vs. alert) gaze_Abstract_1
# 0                                           3.000
# 1                                           4.750
# 2                                           4.375
# 3                                           4.875
# 4                                           2.125
#
# [5 rows x 80 columns]

# %%
cols_to_drop = [' CUE3_Appearance3_Unshaved (vs. shaved)_Abstract_0',
                ' CUE34_Face17_Strong (vs. no) growth of beard_Abstract_0',
                ' CUE53_Mouth2_Yellow (vs. white) teeth_Abstract_0',
                ' CUE62_Set8_Dark (vs. well-lit) background_Abstract_0',
                'No',
                'Sex',
                'BildNr',
                'Trust',
                'Health',
                'Attractiveness',
                ' CUE35_GenImp1_Self confident (vs. not)_Abstract_2',
                ' CUE36_GenImp2_Cautious (vs. risk-seeking)_Abstract_2',  
                ' CUE37_GenImp3_Uneducated (vs. educated)_Abstract_2', 
                ' CUE38_GenImp4_Southern (vs. nordic) type_Abstract_1', 
                ' CUE39_GenImp5_Sporty (vs. unsporty)_Abstract_2',
                ' CUE40_GenImp6_Scruffy (vs. kempt)_Abstract_2',   
                ' CUE41_GenImp7_Likeable (vs. unsympathetic)_Abstract_2',  
                ' CUE42_GenImp8_Attractive (vs. unattractive)_Abstract_2',
                ' CUE43_GenImp9_Irresponsible (vs. responsible)_Abstract_2', 
                ' CUE44_GenImp10_Homosexual (vs. heterosexual)_Abstract_2', 
                ' CUE45_GenImp11_Popular (vs. unpopular)_Abstract_2',   
                ' CUE46_GenImp12_Selfish (vs. unselfish)_Abstract_2',  
                ' CUE47_GenImp13_Ill-looking (vs. healthy-looking)_Abstract_2']#'''

#cols_to_drop = ['No',
#                'Sex']#'''

df = df.drop(cols_to_drop, axis=1)
df.head()
# Out:
#     Risk   CUE1_Appearance1_Ungroomed (vs. groomed) appearance_Abstract_2  \
# 0  3.550                                              4.500
# 1  3.500                                              2.750
# 2  4.775                                              4.625
# 3  4.475                                              3.625
# 4  4.725                                              2.375
#
#     CUE2_Appearance2_Lot of (vs. no) body adornment_Abstract_0  \
# 0                                              4.125
# 1                                              2.125
# 2                                              4.625
# 3                                              5.125
# 4                                              3.250
#
#     CUE4_Appearance4_Worn out (vs. intact) clothes_Abstract_1  \
# 0                                              2.625
# 1                                              2.125
# 2                                              3.250
# 3                                              2.375
# 4                                              1.625
#
#     CUE5_Appearance5_Provocative (vs. reserved) clothes_Abstract_1  \
# 0                                             2.0000
# 1                                             3.6250
# 2                                             2.1429
# 3                                             3.6250
# 4                                             5.1250
#
#     CUE6_Appearance6_Unconventional (vs. conventional) appearance_Abstract_1  \
# 0                                              2.500
# 1                                              3.125
# 2                                              4.000
# 3                                              3.000
# 4                                              4.500
#
#     CUE7_Appearance7_Fashionable (vs. unfashionable) appearance_Abstract_1  \
# 0                                              3.250
# 1                                              4.250
# 2                                              4.125
# 3                                              4.625
# 4                                              5.375
#
#     CUE8_Appearance8_Dark (vs. bright) clothes_Abstract_0  \
# 0                                             5.5000
# 1                                             2.1429
# 2                                             5.7143
# 3                                             2.7500
# 4                                             5.7500
#
#     CUE9_Appearance9_Clean (vs. dirty) clothes_Abstract_1  \
# 0                                              3.500
# 1                                              5.375
# 2                                              3.000
# 3                                              5.000
# 4                                              5.250
#
#     CUE10_Body1_Tense (vs. relaxed) posture_Abstract_1  \
# 0                                              3.000
# 1                                              3.625
# 2                                              4.625
# 3                                              4.625
# 4                                              4.250
#
#                         ...                        \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
#
#     CUE64_Skin1_Unhealthy (vs. healthy) skin_Abstract_1  \
# 0                                              4.375
# 1                                              2.750
# 2                                              3.000
# 3                                              3.500
# 4                                              2.375
#
#     CUE65_Skin2_Pale (vs. tanned) skin_Abstract_0  \
# 0                                           3.250
# 1                                           3.250
# 2                                           6.000
# 3                                           4.875
# 4                                           4.750
#
#     CUE66_Skin3_Pimply (vs. pimple-free) skin_Abstract_0  \
# 0                                              3.750
# 1                                              3.125
# 2                                              2.375
# 3                                              3.375
# 4                                              2.250
#
#     CUE67_Skin4_Many (vs. few) skin folds_Abstract_0  \
# 0                                              2.500
# 1                                              1.500
# 2                                              1.625
# 3                                              1.250
# 4                                              2.000
#
#     CUE68_Skin5_Spotty (vs. spot-free) skin_Abstract_0  \
# 0                                              2.875
# 1                                              1.750
# 2                                              1.500
# 3                                              2.250
# 4                                              2.625
#
#     CUE69_Skin6_Greasy (vs. dry) skin_Abstract_0  \
# 0                                          5.625
# 1                                          4.000
# 2                                          3.250
# 3                                          5.000
# 4                                          4.250
#
#     CUE70_Skin7_Lots of (vs. no) skin visible_Abstract_0  \
# 0                                              6.125
# 1                                              5.250
# 2                                              6.625
# 3                                              5.000
# 4                                              3.125
#
#     CUE71_View1_Coquettish (vs. no coquettish) gaze_Abstract_1  \
# 0                                             2.0000
# 1                                             5.1250
# 2                                             2.5000
# 3                                             4.5000
# 4                                             4.5714
#
#     CUE72_View2_Averted (vs. front-facing) gaze_Abstract_0  \
# 0                                              1.000
# 1                                              1.250
# 2                                              1.625
# 3                                              1.750
# 4                                              1.625
#
#     CUE73_View3_Tired (vs. alert) gaze_Abstract_1
# 0                                           3.000
# 1                                           4.750
# 2                                           4.375
# 3                                           4.875
# 4                                           2.125
#
# [5 rows x 57 columns]

# %%
X_train = df.drop('Risk', axis=1).values
y_train = df['Risk'].values
y_train
# Out:
# array([ 3.55 ,  3.5  ,  4.775,  4.475,  4.725,  2.675,  3.225,  3.75 ,
#         2.25 ,  3.775,  3.7  ,  4.15 ,  4.475,  4.7  ,  2.65 ,  2.95 ,
#         2.825,  4.85 ,  4.125,  3.175,  3.275,  3.3  ,  3.5  ,  2.825,
#         4.45 ,  3.975,  4.55 ,  2.975,  2.725,  4.775,  2.625,  4.45 ,
#         4.975,  4.85 ,  3.925,  3.7  ,  3.225,  2.775,  2.5  ,  3.95 ,
#         1.9  ,  4.65 ,  3.2  ,  4.2  ,  2.175,  4.95 ,  3.25 ,  3.3  ,
#         3.55 ,  4.45 ,  3.525,  3.5  ,  3.525,  3.075,  3.075,  3.425,
#         4.275,  3.95 ,  3.075,  4.175,  3.45 ,  3.05 ,  2.675,  4.475,
#         5.875,  2.825,  3.1  ,  4.725,  3.5  ,  3.575,  3.95 ,  3.8  ,
#         2.7  ,  5.15 ,  3.725,  3.9  ,  2.075,  3.625,  2.925,  3.8  ,
#         3.85 ,  3.525,  3.225,  3.4  ,  2.925,  4.725,  4.35 ,  4.875,
#         3.3  ,  3.375,  5.6  ,  2.425,  5.325,  5.075,  3.2  ,  4.75 ,
#         3.95 ,  1.825,  3.875,  2.275,  2.75 ,  3.025,  2.275,  4.9  ,
#         3.475,  3.7  ,  3.45 ,  5.175,  3.775,  3.075,  3.075,  5.55 ,
#         2.575,  3.275,  3.225,  3.075,  3.45 ,  4.625,  5.65 ,  4.275])

# %%
from string import letters
import numpy as np
import pandas as pd
import seaborn as sns

sns.set(style="white")

# Generate a large random dataset

# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3,
            square=True, xticklabels=5, yticklabels=5,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

# %%
sns.clustermap(df.corr(),  linewidths=.5,
                figsize=(13, 13))
# Out:
# /Users/Ralf/anaconda/lib/python2.7/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
data_set = "/Users/Ralf/My_Cloud/RalfsFunctions/GITHUB/nomcomm/riskcues/data/setB_121-240.txt"
df2 = pd.read_csv(data_set, sep ='\t')
df2.head()

cols_to_drop = [' CUE3_Appearance3_Unshaved (vs. shaved)_Abstract_0',
                ' CUE34_Face17_Strong (vs. no) growth of beard_Abstract_0',
                ' CUE53_Mouth2_Yellow (vs. white) teeth_Abstract_0',
                ' CUE62_Set8_Dark (vs. well-lit) background_Abstract_0',
                'No',
                'Sex',
                'BildNr',
                'Trust',
                'Health',
                'Attractiveness',
                ' CUE35_GenImp1_Self confident (vs. not)_Abstract_2',
                ' CUE36_GenImp2_Cautious (vs. risk-seeking)_Abstract_2',  
                ' CUE37_GenImp3_Uneducated (vs. educated)_Abstract_2', 
                ' CUE38_GenImp4_Southern (vs. nordic) type_Abstract_1', 
                ' CUE39_GenImp5_Sporty (vs. unsporty)_Abstract_2',
                ' CUE40_GenImp6_Scruffy (vs. kempt)_Abstract_2',   
                ' CUE41_GenImp7_Likeable (vs. unsympathetic)_Abstract_2',  
                ' CUE42_GenImp8_Attractive (vs. unattractive)_Abstract_2',
                ' CUE43_GenImp9_Irresponsible (vs. responsible)_Abstract_2', 
                ' CUE44_GenImp10_Homosexual (vs. heterosexual)_Abstract_2', 
                ' CUE45_GenImp11_Popular (vs. unpopular)_Abstract_2',   
                ' CUE46_GenImp12_Selfish (vs. unselfish)_Abstract_2',  
                ' CUE47_GenImp13_Ill-looking (vs. healthy-looking)_Abstract_2']#'''

#cols_to_drop = ['No',
#                'Sex']#'''

df2 = df2.drop(cols_to_drop, axis=1)
df2.head()

X_test = df2.drop('Risk', axis=1).values
y_test = df2['Risk'].values

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import numpy as np

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['is_train'] = np.random.uniform(0, 1, len(df)) <= .75
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)
df.head()

train, test = df[df['is_train']==True], df[df['is_train']==False]

features = df.columns[:4]
clf = RandomForestClassifier(n_jobs=2)
y, _ = pd.factorize(train['species'])
clf.fit(train[features], y)

preds = iris.target_names[clf.predict(test[features])]
pd.crosstab(test['species'], preds, rownames=['actual'], colnames=['preds'])
# Out:
# preds       setosa  versicolor  virginica
# actual
# setosa          10           0          0
# versicolor       0           9          2
# virginica        0           1         15

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder  
from sklearn.ensemble import RandomForestRegressor

#X = np.asarray([('a',1,2),('b',2,3),('a',3,2),('c',1,3)]) 
#y = np.asarray([1,2.5,3,4])

# transform 1st column to numbers
#X[:, 0] = LabelEncoder().fit_transform(X[:,0]) 

regressor = RandomForestRegressor(n_estimators=150)
regressor.fit(X_train, y_train)
#print X
outcome = regressor.predict(X_test)

# %%
#plt.scatter(y_test, outcome)

sns.regplot(y_test, outcome)
plt.axis('square')
plt.xlim([1, 6])
plt.ylim([1, 6])
# Out:
# (1, 6)

# %%
np.corrcoef(y_test, outcome)
# Out:
# array([[ 1.        ,  0.65054013],
#        [ 0.65054013,  1.        ]])

# %%
len(regressor.feature_importances_)
# Out:
# 56

# %%
dd = df2.drop('Risk', axis=1)

# %%
de = pd.DataFrame(index = dd.columns)
de
# Out:
# Empty DataFrame
# Columns: []
# Index: [ CUE1_Appearance1_Ungroomed (vs. groomed) appearance_Abstract_2,  CUE2_Appearance2_Lot of (vs. no) body adornment_Abstract_0,  CUE4_Appearance4_Worn out (vs. intact) clothes_Abstract_1,  CUE5_Appearance5_Provocative (vs. reserved) clothes_Abstract_1,  CUE6_Appearance6_Unconventional (vs. conventional) appearance_Abstract_1,  CUE7_Appearance7_Fashionable (vs. unfashionable) appearance_Abstract_1,  CUE8_Appearance8_Dark (vs. bright) clothes_Abstract_0,  CUE9_Appearance9_Clean (vs. dirty) clothes_Abstract_1,  CUE10_Body1_Tense (vs. relaxed) posture_Abstract_1,  CUE11_Body2_Musculous (vs. not musculous) stature_Abstract_1,  CUE12_Body3_Overweight (vs. underweight)_Abstract_0,  CUE13_Body4_Well (vs. badly) proportioned Stature_Abstract_1,  CUE14_Body5_Tall (vs.low) height_Abstract_0,  CUE15_Eyes1_Dark (vs. no dark) rings under eyes_Abstract_0,  CUE16_Eyes2_Reddened (vs. non-reddened) eyes_Abstract_0,  CUE17_Eyes3_Dark (vs. bright) eyes_Abstract_0,  CUE18_Face1_Happy (vs. sad) expression_Abstract_1,  CUE19_Face2_Babyish (vs. mature) Face_Abstract_1,  CUE20_Face3_Feminine (vs. masculine) face_Abstract_1,  CUE21_Face4_Exhausted (vs. powerful) expression_Abstract_1,  CUE22_Face5_Round (vs. narrow) face_Abstract_0,  CUE23_Face6_Worn (vs. fresh) face_Abstract_1,  CUE24_Face7_Worried (vs. unworried) expression_Abstract_1,  CUE25_Face8_Ugly (vs. beautiful) face_Abstract_1,  CUE26_Face9_Red (vs. pale) cheeks_Abstract_0,  CUE27_Face10_Narrow (vs. full) jaws_Abstract_0,  CUE28_Face11_Serious (vs. blithely) expression_Abstract_1,  CUE29_Face12_Average (vs. unusual) face_Abstract_1,  CUE30_Face13_Angry (vs. cheerful) expression_Abstract_1,  CUE31_Face14_Reddened (vs. non-reddened) face_Abstract_0,  CUE32_Face15_Friendly (vs. grumpy) expression_Abstract_1,  CUE33_Face16_Symmetric (vs. unsymmetric) face_Abstract_0,  CUE48_Hair1_Ungroomed (vs. groomed) hair_Abstract_1,  CUE49_Hair2_Long (vs. short) hair_Abstract_0,  CUE50_Hair3_Fashionable (vs. unfashionable) hairstyle_Abstract_1,  CUE51_Hair4_Dark (vs. bright) hair_Abstract_0,  CUE52_Mouth1_Smile (vs. non smile)_Abstract_0,  CUE54_Mouth3_Full (vs. narrow) lips_Abstract_0,  CUE55_Set1_Pallid (vs. colorful) background_Abstract_0,  CUE56_Set2_Unorganized (vs. organized) background_Abstract_1,  CUE57_Set3_Alcohol (vs. no alcohol) visible_Abstract_0,  CUE58_Set4_Picture taken inside (vs. outside)_Abstract_0,  CUE59_Set5_Picture taken in nature (vs. civilization)_Abstract_0,  CUE60_Set6_Cigarettes (vs. no cigarettes) visible_Abstract_0,  CUE61_Set7_Food (vs. no food) visible_Abstract_0,  CUE63_Set9_During sports activities (vs. not)_Abstract_0,  CUE64_Skin1_Unhealthy (vs. healthy) skin_Abstract_1,  CUE65_Skin2_Pale (vs. tanned) skin_Abstract_0,  CUE66_Skin3_Pimply (vs. pimple-free) skin_Abstract_0,  CUE67_Skin4_Many (vs. few) skin folds_Abstract_0,  CUE68_Skin5_Spotty (vs. spot-free) skin_Abstract_0,  CUE69_Skin6_Greasy (vs. dry) skin_Abstract_0,  CUE70_Skin7_Lots of (vs. no) skin visible_Abstract_0,  CUE71_View1_Coquettish (vs. no coquettish) gaze_Abstract_1,  CUE72_View2_Averted (vs. front-facing) gaze_Abstract_0,  CUE73_View3_Tired (vs. alert) gaze_Abstract_1]

# %%
de['imp'] = regressor.feature_importances_.T
de.head()
# Out:
#                                                          imp
#  CUE1_Appearance1_Ungroomed (vs. groomed) appea...  0.008659
#  CUE2_Appearance2_Lot of (vs. no) body adornmen...  0.141018
#  CUE4_Appearance4_Worn out (vs. intact) clothes...  0.013402
#  CUE5_Appearance5_Provocative (vs. reserved) cl...  0.013197
#  CUE6_Appearance6_Unconventional (vs. conventio...  0.212613

# %%
de.plot(kind = 'bar')

# %%
d = de.rank()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-f4fe80761021> in <module>()
# ----> 1 d.sort_values()
#
# TypeError: sort_values() takes at least 2 arguments (1 given)
